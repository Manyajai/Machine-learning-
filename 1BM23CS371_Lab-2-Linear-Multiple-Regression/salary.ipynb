# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# Load dataset
df = pd.read_csv('salary.csv')

# Check data
print(df.head())

# Define X and y
X = df[['YearsExperience']]
y = df['Salary']

# Create and train model
model = LinearRegression()
model.fit(X, y)

# Predict salary for 12 years experience
prediction_salary = model.predict(pd.DataFrame({'YearsExperience':[12]}))

print("Predicted salary for 12 years experience:", prediction_salary[0])
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 16
#      14 # Create and train model
#      15 model = LinearRegression()
# ---> 16 model.fit(X, y)
#      18 # Predict salary for 12 years experience
#      19 prediction_salary = model.predict(pd.DataFrame({'YearsExperience':[12]}))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# ...

# %%
print(df.isnull().sum())
# Out:
# YearsExperience    2
# Salary             0
# dtype: int64

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

df = pd.read_csv('salary.csv')

# Remove missing values
df = df.dropna()

X = df[['YearsExperience']]
y = df['Salary']

model = LinearRegression()
model.fit(X, y)

prediction = model.predict(pd.DataFrame({'YearsExperience':[12]}))

print("Predicted salary:", prediction[0])
# Out:
# Predicted salary: 139049.67495397784
